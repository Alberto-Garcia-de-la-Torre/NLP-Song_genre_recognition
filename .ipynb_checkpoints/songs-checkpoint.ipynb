# %% [markdown]
# # 2. Data & Preprocessing
#
# ## Loading the dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("akyshnik/lyrics")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/alberto/.cache/kagglehub/datasets/akyshnik/lyrics/versions/1

# %%
import os

print(os.listdir(path))
# Out:
# ['kaggle_clean.csv']

# %%
import pandas as pd

file_path = os.path.join(path, "kaggle_clean.csv")
df = pd.read_csv(file_path)

# %% [markdown]
# ## 2.1 Dataset Selection

# %% [markdown]
# ### Checking the values

# %%
df["genre"].unique()
# Out:
# array(['Pop', 'Hip-Hop', 'Not Available', 'Rock', 'Metal', 'Other',
#        'Country', 'Jazz', 'Electronic', 'Folk', 'R&B', 'Indie'],
#       dtype=object)

# %%
df.info()
df.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266557 entries, 0 to 266556
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  266557 non-null  int64
#  1   index       266557 non-null  int64
#  2   song        266556 non-null  object
#  3   year        266557 non-null  int64
#  4   artist      266557 non-null  object
#  5   genre       266557 non-null  object
#  6   lyrics      266535 non-null  object
#  7   wnum        266557 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 16.3+ MB
#         Unnamed: 0   index                     song  year          artist  \
# 184610      184610  251011       the-way-radio-song  2006     dana-glover
# 156937      156937  214115  noir-your-coloured-soul  2007          canaan
# 29889        29889   41254     it-s-not-about-blame  2006      dunn-holly
# 260520      260520  353750        whatever-it-takes  2007     fairweather
# 261935      261935  355509               sampa-live  2012  caetano-veloso
# 217950      217950  296644            st-ann-s-gold  2008   daniel-lanois
# 47429        47429   66226               odd-couple  2007      the-adicts
# 265732      265732  361323                  someday  2007     dean-martin
# 263286      263286  357712             autumn-child  2007         embraze
# 41629        41629   57961            shores-of-sin  2006     death-angel
#
#                 genre                                             lyrics  wnum
# 184610            Pop  well i guess it's just the way it's got to be\...   323
# 156937           Rock  l?arcobaleno ?na lama nera\ned una carovana ba...   118
# 29889   Not Available  linda hargrove/chris waters\nlove is gone but ...   188
# 260520           Rock  september isn't too far and i'm not sure i'll ...   138
# 261935  Not Available  alguma coisa acontece no meu coraã§ã£o\nque sã...   229
# 217950           Rock  with feet so cold\ni feel no pain\nand the wes...    52
# 47429            Rock  ooh ooh\nshe came from france\nwah wah oo\nshe...   135
# 265732           Jazz  i note that someday you'd want me to want you\...   103
# 263286          Metal  it's getting cold and i feel it coming\nthere ...   111
# 41629           Metal  the crack of dawn fills the empty sky\nwe turn...   140

# %% [markdown]
# ### Modify useless values
#
# We modify every value from the lyrics that are formed by one word to be "instrumental"

# %%
df.loc[df["wnum"] == 1, "lyrics"].value_counts()
# Out:
# lyrics
# instrumental     3645
# instru             51
# instumental        10
# intro              10
# intrumental         9
#                  ...
# orchestra           1
# finntroll           1
# pow!                1
# instermentual       1
# bonus               1
# Name: count, Length: 73, dtype: int64

# %%
df.loc[df["wnum"] == 1, "lyrics"] = "instrumental"
df.loc[df["wnum"] == 1, "lyrics"].value_counts()
# Out:
# lyrics
# instrumental    3842
# Name: count, dtype: int64

# %% [markdown]
# ### Eliminate Non Available values
#
# We do this because there is enough values to being able to eliminate every row that has incomplete information.

# %%
df_clean = df[~df["genre"].isin(["Not Available"])]
df_clean = df_clean[~df_clean["year"].isin([112, 702, 67])]

# %%
print(len(df), len(df_clean))
# Out:
# 266557 242610

# %% [markdown]
# ### Check impact of instrumental songs

# %%
print("Percentage of instrumental songs for each genre:\n")

inst = df_clean["genre"][df_clean["lyrics"] == "instrumental"].value_counts()
no_inst = df_clean["genre"][df_clean["lyrics"] != "instrumental"].value_counts()
genres = inst.keys()

for i in range(len(inst)):
    print(genres[i]+": ", round((inst.iloc[i]/no_inst.iloc[i])*100, 2), "\b%")
# Out:
# Percentage of instrumental songs for each genre:
#
# Rock:  1.31%
# Metal:  1.9%
# Electronic:  1.4%
# Pop:  0.88%
# Jazz:  1.01%
# Folk:  1.73%
# Hip-Hop:  1.12%
# Country:  1.23%
# Indie:  1.33%
# R&B:  0.32%
# Other:  0.28%

# %% [markdown]
# ### Check number of values of each genre

# %%
genre_values = df_clean["genre"].value_counts()
df_size = len(df)
biggest_value = 0
for genre in genres:
    if len(genre) > biggest_value:
        biggest_value = len(genre)
for i in range(len(total)):
    rounded_number = round((genre_values.iloc[i]/df_size)*100, 2)
    print(genres[i]+":"+" "*(biggest_value-len(genres[i])), rounded_number, "\b%")
    print(len(rounded_number))
# Out:
# Rock:       40.98%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 10
#       8 rounded_number = round((genre_values.iloc[i]/df_size)*100, 2)
#       9 print(genres[i]+":"+" "*(biggest_value-len(genres[i])), rounded_number, "\b%")
# ---> 10 print(len(rounded_number))
#
# TypeError: object of type 'numpy.float64' has no len()

# %% [markdown]
# ### Dataset Description
#
# Source: https://www.kaggle.com/datasets/akyshnik/lyrics
# Domain: Prediction of music genre from the lyrics
# Label distribution:
#
# Potential biases:
# Ethical considerations:

# %%
my_list = ["hi", "hello", "hey there"]
print(len(max(my_list, key=len)))  # Output: "hey there"
# Out:
# 9
